# %% [markdown]
# ![Screenshot%202023-12-01%20at%2012.00.19%20PM.png](attachment:Screenshot%202023-12-01%20at%2012.00.19%20PM.png)

# %%
import env
import acquire as a
import prepare as p
import model as m

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
